# %%
import cv2
import os, random
from shutil import copyfile
import fnmatch

# %%
# Image processing
dirwaldo = "data/256/notwaldo"
i=0
for filename in os.listdir(dirwaldo):
    path = os.path.join(dirwaldo, filename)
    newName = "notwaldo256_{0}.jpg".format(str(i))
    print(os.path.join(dirwaldo,newName))
    os.rename(path, os.path.join(dirwaldo,newName))
    i=i+1

# %%
path = "data/waldo/"
i=0
for filename in os.listdir(path):
    if(filename[-4:] == ".png"):
        filepath = path + filename
        image = cv2.imread(filepath)
#         Resize image to 64px width
        r = 64.0 / image.shape[1]
        dim = (64, int(image.shape[0] * r))
        resized = cv2.resize(image, dim, interpolation = cv2.INTER_AREA)
        cv2.imshow("original", resized)
        print resized.shape
        cropped1 = image[0:64, 0:64]
        newName = "waldo_solo{0}.png".format(str(i))
        cv2.imwrite( path + newName, cropped1)
        i+=1
        cropped2 = image[65:128, 0:64]
        newName = "waldo_solo{0}.png".format(str(i))
        cv2.imwrite( path + newName, cropped2)
        i+=1
# Out:
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)
# (145, 64, 3)

# %%
# Picking a random file and insert it on folder to generate not waldo
number_of_files = 200
source_path = "data/train/notwaldo/"
destiny_path = "data/64validation/notwaldo/"
while (len(fnmatch.filter(os.listdir(destiny_path), '*.jpg')) < number_of_files):
    file = random.choice(os.listdir(source_path))
    file_path = source_path + file
    file_destiny_path = destiny_path + file
    print(file_path, file_destiny_path)
    copyfile(file_path,file_destiny_path)
# Out:
# ('data/train/notwaldo/notwaldo64_5220.jpg', 'data/64validation/notwaldo/notwaldo64_5220.jpg')
# ('data/train/notwaldo/notwaldo64_4687.jpg', 'data/64validation/notwaldo/notwaldo64_4687.jpg')
# ('data/train/notwaldo/notwaldo64_1412.jpg', 'data/64validation/notwaldo/notwaldo64_1412.jpg')
# ('data/train/notwaldo/notwaldo64_3624.jpg', 'data/64validation/notwaldo/notwaldo64_3624.jpg')
# ('data/train/notwaldo/notwaldo64_3352.jpg', 'data/64validation/notwaldo/notwaldo64_3352.jpg')
# ('data/train/notwaldo/notwaldo64_2510.jpg', 'data/64validation/notwaldo/notwaldo64_2510.jpg')
# ('data/train/notwaldo/notwaldo64_3062.jpg', 'data/64validation/notwaldo/notwaldo64_3062.jpg')
# ('data/train/notwaldo/notwaldo64_3438.jpg', 'data/64validation/notwaldo/notwaldo64_3438.jpg')
# ('data/train/notwaldo/notwaldo64_3734.jpg', 'data/64validation/notwaldo/notwaldo64_3734.jpg')
# ('data/train/notwaldo/notwaldo64_2864.jpg', 'data/64validation/notwaldo/notwaldo64_2864.jpg')
# ...

# %%
# Data Augmentation for waldo
waldo_samples_train = 400
waldo_samples_test = 100
img_height = 64
img_width = 64

source_path_train = "data/train/waldo/"
source_path_test = "data/test/waldo/"
waldo_train_path = "data/64train/notwaldo/"
waldo_test_path = "data/64test/notwaldo/"

from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
import os
from keras import backend as K

# define data preparation
datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=90)

# configure batch size and retrieve one batch of images
train_generator = train_datagen.flow_from_directory(
        source_path_train,
        target_size=(img_width, img_height),
        batch_size=32,
        class_mode='binary', 
        save_to_dir=waldo_train_path,
        save_prefix="waldo_train")
